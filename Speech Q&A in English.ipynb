# %% [markdown]
# ## using OpenAI

# %%
import speech_recognition as sr
import pyttsx3
import openai

# Set up the OpenAI GPT API
openai.api_key = "enter your security key"

# Function to convert speech to text using Google Speech Recognition
def speech_to_text_google():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Please ask your question...")
        # Listen to the microphone with a phrase time limit of 10 seconds
        try:
            audio_data = recognizer.listen(source, timeout=5, phrase_time_limit=10)
            text = recognizer.recognize_google(audio_data, language='en-US')  # Recognize English
            return text
        except sr.UnknownValueError:
            return "I could not understand the question."
        except sr.RequestError as e:
            return f"Could not request results; {e}"
        except sr.WaitTimeoutError:
            return "Listening timed out while waiting for the phrase to start."

# Function to get a response from GPT using the chat model
def get_gpt_response(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",  # You can also use 'gpt-4' if available
        messages=[
            {"role": "system", "content": "You are an assistant that answers questions in English."},
            {"role": "user", "content": prompt}
        ]
    )
    return response['choices'][0]['message']['content'].strip()

# Function to convert text to speech using pyttsx3
def text_to_speech_english(text):
    engine = pyttsx3.init()
    voices = engine.getProperty('voices')
    
    # Set English voice if available
    for voice in voices:
        if 'english' in voice.name.lower():
            engine.setProperty('voice', voice.id)
            break
    
    engine.say(text)
    engine.runAndWait()

# Main workflow function
def process_speech_and_respond():
    # Step 1: Convert speech to text (English input)
    input_text = speech_to_text_google()
    print(f"Recognized speech: {input_text}")
    
    if "Google Speech Recognition" in input_text:
        print("Error in speech recognition")
        return
    
    # Step 2: Get GPT response in text
    gpt_response = get_gpt_response(input_text)
    print(f"GPT Response: {gpt_response}")
    
    # Step 3: Convert GPT response to speech
    text_to_speech_english(gpt_response)

# Example usage
if __name__ == "__main__":
    print("Welcome to the GPT-2 Q&A system. Ask your question by speaking.")
    while True:
        # Run the main process to handle input and response
        process_speech_and_respond()

        # Optional exit condition to stop the program
        user_input = input("Do you want to ask another question? (yes/no): ").strip().lower()
        if user_input in ["no", "n", "exit", "quit", "stop"]:
            print("Exiting the Q&A system. Goodbye!")
            break
# Out:
# Welcome to the GPT-2 Q&A system. Ask your question by speaking.
# Please ask your question...
# Recognized speech: IGBT basically I am here to get some information about the GPT for API fine tuning tell me about this
# GPT Response: It seems like there might be a mix-up in the terms you mentioned. IGBT stands for Insulated Gate Bipolar Transistor, a type of semiconductor device used for switching applications in electronics.
#
# On the other hand, GPT stands for Generative Pre-trained Transformer, which is a type of machine learning model commonly used for natural language processing tasks like text generation. API fine-tuning typically refers to the process of fine-tuning a pre-trained model like GPT on a specific dataset or task to improve its performance.
#
# If you are looking for information on fine-tuning GPT for specific tasks, there are resources available online that provide detailed tutorials and guides on how to do so. Would you like further information on this topic?
# ...

# %%
## Using Microphone

# %%
import speech_recognition as sr
import pyttsx3
import openai

# Set up the OpenAI GPT API
openai.api_key = "give your security key"  # Replace with your OpenAI API key

# Function to convert speech to text using Google Speech Recognition
def speech_to_text_google():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Please ask your question or say 'exit' to quit...")
        # Listen to the microphone with a phrase time limit of 10 seconds
        try:
            audio_data = recognizer.listen(source, timeout=5, phrase_time_limit=10)
            text = recognizer.recognize_google(audio_data, language='en-US')  # Recognize English
            return text
        except sr.UnknownValueError:
            return "I could not understand the question."
        except sr.RequestError as e:
            return f"Could not request results; {e}"
        except sr.WaitTimeoutError:
            return "Listening timed out while waiting for the phrase to start."

# Function to get a response from GPT using the chat model
def get_gpt_response(prompt):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",  # You can also use 'gpt-4' if available
        messages=[
            {"role": "system", "content": "You are an assistant that answers questions in English."},
            {"role": "user", "content": prompt}
        ]
    )
    return response['choices'][0]['message']['content'].strip()

# Function to convert text to speech using pyttsx3
def text_to_speech_english(text):
    engine = pyttsx3.init()
    voices = engine.getProperty('voices')
    
    # Set English voice if available
    for voice in voices:
        if 'english' in voice.name.lower():
            engine.setProperty('voice', voice.id)
            break
    
    engine.say(text)
    engine.runAndWait()

# Main workflow function
def process_speech_and_respond():
    # Step 1: Convert speech to text (English input)
    input_text = speech_to_text_google()
    print(f"Recognized speech: {input_text}")
    
    # Check for verbal exit command
    if input_text.lower() in ["exit", "quit", "stop"]:
        print("Exit command received. Exiting the program.")
        return False  # Signal to exit the main loop

    if "Google Speech Recognition" in input_text:
        print("Error in speech recognition")
        return True  # Continue the loop

    # Step 2: Get GPT response in text
    gpt_response = get_gpt_response(input_text)
    print(f"GPT Response: {gpt_response}")
    
    # Step 3: Convert GPT response to speech
    text_to_speech_english(gpt_response)
    
    return True  # Continue the loop

# Example usage
if __name__ == "__main__":
    print("Welcome to the GPT-2 Q&A system. Ask your question by speaking.")
    while True:
        # Run the main process to handle input and response
        continue_loop = process_speech_and_respond()
        
        # Break the loop if the verbal exit command was received
        if not continue_loop:
            break

    print("Exiting the Q&A system. Goodbye!")
# Out:
# Welcome to the GPT-2 Q&A system. Ask your question by speaking.
# Please ask your question or say 'exit' to quit...
# Recognized speech: hello how are you
# GPT Response: Hello! I'm here to assist you. How can I help you today?
# Please ask your question or say 'exit' to quit...
# Recognized speech: so tell me something about yourself
# GPT Response: Hello! I am an AI assistant programmed to help users with their questions and provide information on various topics. I am here to assist you with any queries you may have, so feel free to ask me anything!
# Please ask your question or say 'exit' to quit...
# Recognized speech: can you speak German language
# GPT Response: Yes, I can understand and communicate in German. How can I assist you today?
# Please ask your question or say 'exit' to quit...
# Recognized speech: so I will speak in English and you have to translate in German language ok so what should tell me like
# ...
